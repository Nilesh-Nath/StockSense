# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import io
import os

# Function to save plot as byte stream
def save_plot_to_bytes(fig):
    img_stream = io.BytesIO()
    fig.savefig(img_stream, format='png')
    img_stream.seek(0)  # Reset the stream pointer to the beginning
    return img_stream

# Get list of tickers (file names without extensions) from the directory
list_of_tickers = os.listdir('../stock_data_csv')
tickers_without_extension = [os.path.splitext(ticker)[0] for ticker in list_of_tickers if ticker.endswith('.csv')]

# Iterate through each ticker and perform EDA
for ticker in tickers_without_extension:
    # Load the dataset
    df = pd.read_csv(f"../stock_data_csv/{ticker}.csv")
    df["published_date"] = pd.to_datetime(df["published_date"])
    df.sort_values("published_date", inplace=True)
    # Perform EDA
    eda_stats = df.describe()
    missing_values = df.isnull().sum()
    correlation_matrix = df.drop(columns=['status']).corr() if 'status' in df.columns else df.corr()
    
    # Print results for verification (optional)
    print(f"Dataset Overview for {ticker}:")
    print(df.info())
    print(f"\nDescriptive Statistics for {ticker}:")
    print(eda_stats)
    print(f"\nMissing Values for {ticker}:")
    print(missing_values)
    print(f"\nCorrelation Matrix for {ticker}:")
    print(correlation_matrix)
    
    # Save Closing Price Plot as byte stream
    plt.figure(figsize=(10, 5))
    sns.lineplot(x=df["published_date"], y=df["close"], label="Close Price")
    plt.title(f"{ticker} Stock Closing Price Over Time")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.legend()
    closing_price_img_stream = save_plot_to_bytes(plt.gcf())  # Save plot to byte stream
    plt.close()

    # Moving Averages Plot
    df['10-day MA'] = df['close'].rolling(window=10).mean()
    df['50-day MA'] = df['close'].rolling(window=50).mean()
    plt.figure(figsize=(12, 6))
    plt.plot(df['close'], label='Closing Price', alpha=0.8)
    plt.plot(df['10-day MA'], label='10-day MA', linestyle='dashed')
    plt.plot(df['50-day MA'], label='50-day MA', linestyle='dashed')
    plt.legend()
    moving_avg_img_stream = save_plot_to_bytes(plt.gcf())  # Save plot to byte stream
    plt.close()

    # Heatmap Plot for Correlation
    plt.figure(figsize=(8, 5))
    sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title(f"{ticker} Feature Correlation Matrix")
    heatmap_img_stream = save_plot_to_bytes(plt.gcf())  # Save plot to byte stream
    plt.close()

    # Combine all results into a dictionary
    eda_results = {
        'dataframe': df,
        'eda_statistics': eda_stats,
        'missing_values': missing_values,
        'correlation_matrix': correlation_matrix,
        'closing_price_plot': closing_price_img_stream,
        'moving_avg_plot': moving_avg_img_stream,
        'heatmap_plot': heatmap_img_stream
    }

    # Save the results for each ticker in a separate joblib file
    joblib.dump(eda_results, f'./EDA_Results/eda_results_{ticker}.joblib')

    print(f"\nEDA results and plots for {ticker} have been saved into 'eda_results_{ticker}.joblib'")
# Out:
# Dataset Overview for AHPC:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3287 entries, 0 to 3286
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   3287 non-null   datetime64[ns]
#  1   open             3287 non-null   float64
#  2   high             3287 non-null   float64
#  3   low              3287 non-null   float64
#  4   close            3287 non-null   float64
#  5   per_change       3286 non-null   float64
#  6   traded_quantity  3287 non-null   float64
#  7   traded_amount    3287 non-null   float64
#  8   status           3287 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 256.8 KB
# None
#
# Descriptive Statistics for AHPC:
#                       published_date         open         high          low  \
# count                           3287  3287.000000  3287.000000  3287.000000
# mean   2017-06-07 15:15:10.130818560   303.771828   309.009644   297.656009
# min              2009-11-25 00:00:00    90.000000    91.000000    88.000000
# 25%              2013-10-29 12:00:00   213.000000   216.000000   209.000000
# 50%              2017-06-19 00:00:00   301.000000   305.000000   297.000000
# 75%              2021-02-26 12:00:00   384.000000   391.000000   375.000000
# max              2024-08-15 00:00:00   790.000000   790.000000   790.000000
# std                              NaN   128.143984   131.009409   125.256783
#
#              close   per_change  traded_quantity  traded_amount       status
# count  3287.000000  3286.000000     3.287000e+03   3.287000e+03  3287.000000
# mean    303.305993     0.046905     6.003239e+04   2.311481e+07    -0.064192
# min      90.000000   -40.150000     1.000000e+01   0.000000e+00    -1.000000
# 25%     213.000000    -1.537500     1.555000e+03   2.904695e+05     0.000000
# 50%     301.000000     0.000000     6.710000e+03   1.585337e+06     0.000000
# 75%     384.000000     1.277500     4.162350e+04   1.151959e+07     0.000000
# max     790.000000    20.620000     1.896335e+06   1.318345e+09     1.000000
# std     127.967173     3.017519     1.570523e+05   7.836907e+07     0.637501
#
# Missing Values for AHPC:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for AHPC:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.388263 -0.377682 -0.403800 -0.394078
# open                  -0.388263  1.000000  0.996487  0.996348  0.995103
# high                  -0.377682  0.996487  1.000000  0.997906  0.998747
# low                   -0.403800  0.996348  0.997906  1.000000  0.998518
# close                 -0.394078  0.995103  0.998747  0.998518  1.000000
# per_change             0.033580 -0.038694  0.006695 -0.002948  0.030954
# traded_quantity        0.402598  0.245198  0.260667  0.231221  0.248909
# traded_amount          0.298888  0.354936  0.368632  0.341698  0.357335
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.033580         0.402598       0.298888
# open              -0.038694         0.245198       0.354936
# high               0.006695         0.260667       0.368632
# low               -0.002948         0.231221       0.341698
# close              0.030954         0.248909       0.357335
# per_change         1.000000         0.161717       0.111556
# traded_quantity    0.161717         1.000000       0.918149
# traded_amount      0.111556         0.918149       1.000000
#
# EDA results and plots for AHPC have been saved into 'eda_results_AHPC.joblib'
# Dataset Overview for AKJCL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1287 entries, 0 to 1286
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1287 non-null   datetime64[ns]
#  1   open             1287 non-null   float64
#  2   high             1287 non-null   float64
#  3   low              1287 non-null   float64
#  4   close            1287 non-null   float64
#  5   per_change       1287 non-null   float64
#  6   traded_quantity  1287 non-null   float64
#  7   traded_amount    1287 non-null   float64
#  8   status           1287 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 100.5 KB
# None
#
# Descriptive Statistics for AKJCL:
#                       published_date         open         high          low  \
# count                           1287  1287.000000  1287.000000  1287.000000
# mean   2021-11-06 08:25:44.055943936   176.140085   180.668967   171.377498
# min              2018-12-25 00:00:00    47.040000    48.960000    46.400000
# 25%              2020-07-28 12:00:00    83.000000    85.000000    81.000000
# 50%              2021-11-29 00:00:00   180.000000   183.600000   175.100000
# 75%              2023-04-04 12:00:00   227.000000   232.000000   221.000000
# max              2024-08-15 00:00:00   502.000000   502.000000   456.600000
# std                              NaN    89.648228    92.203030    86.258174
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1287.000000  1287.000000      1287.000000   1.287000e+03  1287.000000
# mean    175.725408     0.165276     39039.081585   9.612744e+06    -0.133644
# min      48.000000   -10.000000        10.000000   5.500000e+02    -1.000000
# 25%      82.500000    -1.790000      2096.500000   1.572590e+05    -1.000000
# 50%     179.000000    -0.050000     17272.000000   3.330176e+06    -1.000000
# 75%     225.450000     1.550000     45920.000000   1.014875e+07     1.000000
# max     492.400000    10.000000    927002.000000   3.157153e+08     1.000000
# std      88.877778     3.415675     66421.540803   1.851433e+07     0.940291
#
# Missing Values for AKJCL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         0
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for AKJCL:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.570455  0.565531  0.581776  0.572009
# open                   0.570455  1.000000  0.998474  0.998455  0.996667
# high                   0.565531  0.998474  1.000000  0.998098  0.998770
# low                    0.581776  0.998455  0.998098  1.000000  0.998060
# close                  0.572009  0.996667  0.998770  0.998060  1.000000
# per_change             0.023699 -0.026340  0.009702 -0.002694  0.039231
# traded_quantity        0.371637  0.458094  0.470587  0.456624  0.469049
# traded_amount          0.297558  0.502065  0.514152  0.499637  0.512283
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.023699         0.371637       0.297558
# open              -0.026340         0.458094       0.502065
# high               0.009702         0.470587       0.514152
# low               -0.002694         0.456624       0.499637
# close              0.039231         0.469049       0.512283
# per_change         1.000000         0.161062       0.131687
# traded_quantity    0.161062         1.000000       0.971656
# traded_amount      0.131687         0.971656       1.000000
#
# EDA results and plots for AKJCL have been saved into 'eda_results_AKJCL.joblib'
# Dataset Overview for AKPL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1637 entries, 0 to 1636
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1637 non-null   datetime64[ns]
#  1   open             1637 non-null   float64
#  2   high             1637 non-null   float64
#  3   low              1637 non-null   float64
#  4   close            1637 non-null   float64
#  5   per_change       1636 non-null   float64
#  6   traded_quantity  1637 non-null   float64
#  7   traded_amount    1637 non-null   float64
#  8   status           1637 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 127.9 KB
# None
#
# Descriptive Statistics for AKPL:
#                       published_date         open         high          low  \
# count                           1637  1637.000000  1637.000000  1637.000000
# mean   2021-01-31 14:43:10.592547328   298.910202   304.978375   291.965425
# min              2017-07-02 00:00:00   104.000000   107.000000   100.000000
# 25%              2019-03-28 00:00:00   181.000000   184.000000   177.000000
# 50%              2021-03-03 00:00:00   270.000000   276.000000   264.000000
# 75%              2022-11-14 00:00:00   397.000000   402.000000   390.100000
# max              2024-08-15 00:00:00   843.500000   882.400000   805.000000
# std                              NaN   137.902872   141.035590   133.714447
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1637.000000  1636.000000     1.637000e+03   1.637000e+03  1637.000000
# mean    298.115699     0.073710     1.000014e+05   3.651890e+07    -0.136836
# min     106.000000   -10.000000     1.000000e+01   1.380000e+03    -1.000000
# 25%     181.000000    -1.690000     2.751000e+03   6.848140e+05    -1.000000
# 50%     269.000000    -0.295000     4.192000e+04   9.067869e+06     0.000000
# 75%     395.000000     1.470000     1.156190e+05   3.937562e+07     1.000000
# max     830.500000    10.000000     1.395526e+06   1.167832e+09     1.000000
# std     136.786092     2.956305     1.659866e+05   7.572061e+07     0.916885
#
# Missing Values for AKPL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for AKPL:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.148609  0.149069  0.147927  0.145062
# open                   0.148609  1.000000  0.998619  0.998919  0.997127
# high                   0.149069  0.998619  1.000000  0.998547  0.998924
# low                    0.147927  0.998919  0.998547  1.000000  0.998579
# close                  0.145062  0.997127  0.998924  0.998579  1.000000
# per_change             0.036667 -0.018511  0.016625  0.003876  0.042700
# traded_quantity        0.332484  0.288943  0.305671  0.281348  0.296210
# traded_amount          0.226846  0.503409  0.519990  0.496431  0.509729
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.036667         0.332484       0.226846
# open              -0.018511         0.288943       0.503409
# high               0.016625         0.305671       0.519990
# low                0.003876         0.281348       0.496431
# close              0.042700         0.296210       0.509729
# per_change         1.000000         0.228194       0.162124
# traded_quantity    0.228194         1.000000       0.874987
# traded_amount      0.162124         0.874987       1.000000
#
# EDA results and plots for AKPL have been saved into 'eda_results_AKPL.joblib'
# Dataset Overview for API:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1987 entries, 0 to 1986
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1987 non-null   datetime64[ns]
#  1   open             1987 non-null   float64
#  2   high             1987 non-null   float64
#  3   low              1987 non-null   float64
#  4   close            1987 non-null   float64
#  5   per_change       1986 non-null   float64
#  6   traded_quantity  1987 non-null   float64
#  7   traded_amount    1987 non-null   float64
#  8   status           1987 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 155.2 KB
# None
#
# Descriptive Statistics for API:
#                       published_date         open         high          low  \
# count                           1987  1987.000000  1987.000000  1987.000000
# mean   2020-04-27 21:06:47.649723136   323.205531   330.030146   315.250679
# min              2015-12-29 00:00:00   100.000000   102.000000   100.000000
# 25%              2018-02-27 12:00:00   175.500000   177.950000   172.000000
# 50%              2020-03-12 00:00:00   267.000000   272.000000   260.000000
# 75%              2022-07-05 12:00:00   450.000000   464.000000   436.500000
# max              2024-08-15 00:00:00   880.000000   888.000000   851.000000
# std                              NaN   179.548552   183.581595   174.931875
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1987.000000  1986.000000     1.987000e+03   1.987000e+03  1987.000000
# mean    322.609210     0.094804     1.136005e+05   3.787108e+07    -0.110216
# min     100.000000   -10.000000     1.100000e+02   3.770100e+04    -1.000000
# 25%     174.050000    -1.640000     5.258500e+03   1.513458e+06    -1.000000
# 50%     266.100000    -0.175000     3.310800e+04   7.804868e+06     0.000000
# 75%     449.000000     1.360000     1.318035e+05   3.216616e+07     1.000000
# max     880.000000    10.000000     2.237172e+06   8.638247e+08     1.000000
# std     179.423534     3.038421     2.021144e+05   8.254171e+07     0.827176
#
# Missing Values for API:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for API:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.530910 -0.531474 -0.533310 -0.535573
# open                  -0.530910  1.000000  0.998832  0.998963  0.997755
# high                  -0.531474  0.998832  1.000000  0.998779  0.999075
# low                   -0.533310  0.998963  0.998779  1.000000  0.998927
# close                 -0.535573  0.997755  0.999075  0.998927  1.000000
# per_change             0.027020 -0.024609  0.007605 -0.000052  0.031450
# traded_quantity        0.447805  0.031085  0.040724  0.025929  0.034839
# traded_amount          0.324290  0.174571  0.183534  0.168922  0.177323
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.027020         0.447805       0.324290
# open              -0.024609         0.031085       0.174571
# high               0.007605         0.040724       0.183534
# low               -0.000052         0.025929       0.168922
# close              0.031450         0.034839       0.177323
# per_change         1.000000         0.220371       0.176261
# traded_quantity    0.220371         1.000000       0.924838
# traded_amount      0.176261         0.924838       1.000000
#
# EDA results and plots for API have been saved into 'eda_results_API.joblib'
# Dataset Overview for BARUN:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1937 entries, 0 to 1936
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1937 non-null   datetime64[ns]
#  1   open             1937 non-null   float64
#  2   high             1937 non-null   float64
#  3   low              1937 non-null   float64
#  4   close            1937 non-null   float64
#  5   per_change       1936 non-null   float64
#  6   traded_quantity  1937 non-null   float64
#  7   traded_amount    1937 non-null   float64
#  8   status           1937 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 151.3 KB
# None
#
# Descriptive Statistics for BARUN:
#                       published_date         open         high          low  \
# count                           1937  1937.000000  1937.000000  1937.000000
# mean   2020-04-26 03:42:16.912751872   263.872685   269.426174   257.740268
# min              2015-10-28 00:00:00    76.000000    76.000000    76.000000
# 25%              2018-01-29 00:00:00   172.000000   175.000000   166.000000
# 50%              2020-07-20 00:00:00   242.000000   247.000000   237.000000
# 75%              2022-07-21 00:00:00   330.000000   337.000000   325.000000
# max              2024-08-15 00:00:00   735.000000   763.400000   704.900000
# std                              NaN   137.383447   141.442332   132.601244
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1937.000000  1936.000000      1937.000000   1.937000e+03  1937.000000
# mean    263.478317     0.075274     20655.556531   7.468414e+06    -0.082086
# min      76.000000    -9.570000        10.000000   7.700000e+02    -1.000000
# 25%     170.000000    -1.740000       310.000000   5.443000e+04    -1.000000
# 50%     241.000000     0.000000      3007.000000   6.171309e+05     0.000000
# 75%     330.000000     1.410000     20607.000000   6.116070e+06     1.000000
# max     750.000000    10.000000    515725.000000   1.964589e+08     1.000000
# std     136.721161     3.128448     44360.613144   1.871542e+07     0.820687
#
# Missing Values for BARUN:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for BARUN:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.074188  0.085294  0.066938  0.073136
# open                   0.074188  1.000000  0.998348  0.998619  0.996948
# high                   0.085294  0.998348  1.000000  0.998234  0.998706
# low                    0.066938  0.998619  0.998234  1.000000  0.998569
# close                  0.073136  0.996948  0.998706  0.998569  1.000000
# per_change             0.044217 -0.018716  0.018590  0.008837  0.045989
# traded_quantity        0.424441  0.327244  0.345918  0.321422  0.337172
# traded_amount          0.345781  0.453623  0.472226  0.447715  0.463307
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.044217         0.424441       0.345781
# open              -0.018716         0.327244       0.453623
# high               0.018590         0.345918       0.472226
# low                0.008837         0.321422       0.447715
# close              0.045989         0.337172       0.463307
# per_change         1.000000         0.205956       0.178302
# traded_quantity    0.205956         1.000000       0.933409
# traded_amount      0.178302         0.933409       1.000000
#
# EDA results and plots for BARUN have been saved into 'eda_results_BARUN.joblib'
# Dataset Overview for BFC:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1437 entries, 0 to 1436
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1437 non-null   datetime64[ns]
#  1   open             1437 non-null   float64
#  2   high             1437 non-null   float64
#  3   low              1437 non-null   float64
#  4   close            1437 non-null   float64
#  5   per_change       1436 non-null   float64
#  6   traded_quantity  1437 non-null   float64
#  7   traded_amount    1437 non-null   float64
#  8   status           1437 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 112.3 KB
# None
#
# Descriptive Statistics for BFC:
#                       published_date         open         high          low  \
# count                           1437  1437.000000  1437.000000  1437.000000
# mean   2021-04-19 00:30:03.757828608   270.090466   275.872582   263.796451
# min              2011-06-26 00:00:00    80.000000    80.000000    80.000000
# 25%              2019-11-04 00:00:00   119.000000   120.000000   118.000000
# 50%              2021-08-01 00:00:00   306.000000   311.800000   302.000000
# 75%              2023-02-02 00:00:00   382.000000   392.000000   371.000000
# max              2024-08-15 00:00:00   704.000000   720.000000   672.200000
# std                              NaN   148.570217   152.563301   144.005687
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1437.000000  1436.000000      1437.000000   1.437000e+03  1437.000000
# mean    269.236604     0.098760     23569.452331   8.977707e+06    -0.092554
# min      80.000000   -38.510000        10.000000   9.900000e+02    -1.000000
# 25%     119.000000    -1.670000      2385.000000   3.616900e+05    -1.000000
# 50%     307.000000     0.000000      9490.000000   2.209644e+06     0.000000
# 75%     380.000000     1.612500     24604.000000   7.883816e+06     1.000000
# max     690.400000    21.430000    299963.000000   1.710517e+08     1.000000
# std     147.660042     3.448919     38920.169743   1.811188e+07     0.906757
#
# Missing Values for BFC:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for BFC:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.502571  0.505742  0.503447  0.504438
# open                   0.502571  1.000000  0.998599  0.998467  0.997165
# high                   0.505742  0.998599  1.000000  0.998547  0.998984
# low                    0.503447  0.998467  0.998547  1.000000  0.998803
# close                  0.504438  0.997165  0.998984  0.998803  1.000000
# per_change             0.043743 -0.001647  0.032402  0.026859  0.056795
# traded_quantity        0.252012  0.447430  0.465663  0.438706  0.459216
# traded_amount          0.265456  0.557840  0.574244  0.550634  0.568394
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.043743         0.252012       0.265456
# open              -0.001647         0.447430       0.557840
# high               0.032402         0.465663       0.574244
# low                0.026859         0.438706       0.550634
# close              0.056795         0.459216       0.568394
# per_change         1.000000         0.235786       0.187257
# traded_quantity    0.235786         1.000000       0.932311
# traded_amount      0.187257         0.932311       1.000000
#
# EDA results and plots for BFC have been saved into 'eda_results_BFC.joblib'
# Dataset Overview for BOKL:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1294 non-null   datetime64[ns]
#  1   open             1294 non-null   float64
#  2   high             1294 non-null   float64
#  3   low              1294 non-null   float64
#  4   close            1294 non-null   float64
#  5   per_change       1293 non-null   float64
#  6   traded_quantity  1294 non-null   float64
#  7   traded_amount    1294 non-null   float64
#  8   status           1294 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 91.1 KB
# None
#
# Descriptive Statistics for BOKL:
#                       published_date        open         high          low  \
# count                           1294  1294.00000  1294.000000  1294.000000
# mean   2019-09-14 05:03:48.129829888   328.65425   332.906723   323.215301
# min              2016-11-20 00:00:00   196.00000   200.000000   195.200000
# 25%              2018-04-15 06:00:00   256.00000   259.000000   252.000000
# 50%              2019-08-06 12:00:00   303.00000   306.000000   297.000000
# 75%              2021-03-06 06:00:00   382.75000   387.000000   375.000000
# max              2023-01-08 00:00:00   675.00000   688.000000   654.000000
# std                              NaN   100.07779   101.598392    98.304609
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1294.000000  1293.000000      1294.000000   1.294000e+03  1294.000000
# mean    327.600696    -0.027610     47612.749614   1.573500e+07    -0.068779
# min     197.000000   -22.120000        70.000000   1.452000e+04    -1.000000
# 25%     255.000000    -1.080000     12140.750000   3.687824e+06    -1.000000
# 50%     302.000000    -0.020000     23407.500000   7.297183e+06     0.000000
# 75%     379.750000     0.880000     49544.250000   1.660696e+07     1.000000
# max     669.000000     9.300000    980144.000000   3.401249e+08     1.000000
# std      99.945514     1.991164     71593.472907   2.436828e+07     0.826326
#
# Missing Values for BOKL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for BOKL:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.620877 -0.618769 -0.626782 -0.623780
# open                  -0.620877  1.000000  0.998631  0.998759  0.997858
# high                  -0.618769  0.998631  1.000000  0.998216  0.998889
# low                   -0.626782  0.998759  0.998216  1.000000  0.998802
# close                 -0.623780  0.997858  0.998889  0.998802  1.000000
# per_change             0.023728 -0.051775 -0.020921 -0.029826  0.000283
# traded_quantity        0.345997  0.017627  0.030996  0.010031  0.023362
# traded_amount          0.255790  0.161598  0.175324  0.153764  0.167705
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.023728         0.345997       0.255790
# open              -0.051775         0.017627       0.161598
# high              -0.020921         0.030996       0.175324
# low               -0.029826         0.010031       0.153764
# close              0.000283         0.023362       0.167705
# per_change         1.000000         0.234861       0.223665
# traded_quantity    0.234861         1.000000       0.977597
# traded_amount      0.223665         0.977597       1.000000
#
# EDA results and plots for BOKL have been saved into 'eda_results_BOKL.joblib'
# Dataset Overview for BPCL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3287 entries, 0 to 3286
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   3287 non-null   datetime64[ns]
#  1   open             3287 non-null   float64
#  2   high             3287 non-null   float64
#  3   low              3287 non-null   float64
#  4   close            3287 non-null   float64
#  5   per_change       3286 non-null   float64
#  6   traded_quantity  3287 non-null   float64
#  7   traded_amount    3287 non-null   float64
#  8   status           3287 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 256.8 KB
# None
#
# Descriptive Statistics for BPCL:
#                       published_date         open         high          low  \
# count                           3287  3287.000000  3287.000000  3287.000000
# mean   2016-11-30 16:42:20.918770688   586.271363   593.236748   579.522695
# min              2005-01-20 00:00:00   280.000000   280.000000   250.000000
# 25%              2013-07-02 12:00:00   385.200000   393.000000   377.500000
# 50%              2017-06-27 00:00:00   519.000000   526.000000   510.000000
# 75%              2021-02-26 12:00:00   725.000000   735.000000   715.000000
# max              2024-08-15 00:00:00  1820.000000  1820.000000  1815.000000
# std                              NaN   269.228767   270.883101   268.069617
#
#              close   per_change  traded_quantity  traded_amount      status
# count  3287.000000  3286.000000      3287.000000   3.287000e+03  3287.00000
# mean    586.001917     0.116251     14631.477943   6.981520e+06    -0.05111
# min     280.000000   -68.630000         0.000000   0.000000e+00    -1.00000
# 25%     385.000000    -1.207500       817.000000   3.091750e+05     0.00000
# 50%     518.000000     0.000000      3560.000000   1.608898e+06     0.00000
# 75%     725.000000     1.130000     11396.000000   4.919359e+06     0.00000
# max    1820.000000   218.750000    730116.000000   4.128570e+08     1.00000
# std     269.671661     4.965658     40762.561396   2.154304e+07     0.65352
#
# Missing Values for BPCL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for BPCL:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.699602 -0.695395 -0.703710 -0.701270
# open                  -0.699602  1.000000  0.990392  0.990765  0.989760
# high                  -0.695395  0.990392  1.000000  0.998726  0.999283
# low                   -0.703710  0.990765  0.998726  1.000000  0.999259
# close                 -0.701270  0.989760  0.999283  0.999259  1.000000
# per_change            -0.035477 -0.038651  0.076829  0.072617  0.086056
# traded_quantity        0.274405 -0.122914 -0.113567 -0.129012 -0.121388
# traded_amount          0.233201 -0.076361 -0.066166 -0.082422 -0.074377
#
#                  per_change  traded_quantity  traded_amount
# published_date    -0.035477         0.274405       0.233201
# open              -0.038651        -0.122914      -0.076361
# high               0.076829        -0.113567      -0.066166
# low                0.072617        -0.129012      -0.082422
# close              0.086056        -0.121388      -0.074377
# per_change         1.000000         0.056568       0.056252
# traded_quantity    0.056568         1.000000       0.980129
# traded_amount      0.056252         0.980129       1.000000
#
# EDA results and plots for BPCL have been saved into 'eda_results_BPCL.joblib'
# Dataset Overview for CBL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1854 entries, 0 to 1853
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1854 non-null   datetime64[ns]
#  1   open             1854 non-null   float64
#  2   high             1854 non-null   float64
#  3   low              1854 non-null   float64
#  4   close            1854 non-null   float64
#  5   per_change       1853 non-null   float64
#  6   traded_quantity  1854 non-null   float64
#  7   traded_amount    1854 non-null   float64
#  8   status           1854 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 144.8 KB
# None
#
# Descriptive Statistics for CBL:
#                       published_date         open         high          low  \
# count                           1854  1854.000000  1854.000000  1854.000000
# mean   2018-07-07 10:50:52.427184384   214.068770   217.630313   210.214779
# min              2013-05-19 00:00:00   128.000000   134.000000   125.000000
# 25%              2015-12-23 06:00:00   155.250000   158.000000   153.000000
# 50%              2018-09-12 12:00:00   221.000000   225.000000   217.200000
# 75%              2020-11-08 18:00:00   260.000000   265.000000   255.000000
# max              2023-02-23 00:00:00   355.000000   369.000000   348.000000
# std                              NaN    56.615355    58.175745    55.099943
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1854.000000  1853.000000     1.854000e+03   1.854000e+03  1854.000000
# mean    213.832686     0.058203     6.752713e+04   1.519783e+07    -0.035059
# min     129.000000   -16.740000     5.000000e+01   8.000000e+03    -1.000000
# 25%     155.000000    -1.140000     1.342425e+04   2.712547e+06    -1.000000
# 50%     220.900000     0.000000     2.823100e+04   5.798240e+06     0.000000
# 75%     260.000000     0.820000     7.235625e+04   1.512627e+07     0.000000
# max     355.000000    10.000000     1.187423e+06   3.082923e+08     1.000000
# std      56.522507     2.154459     1.130756e+05   2.790896e+07     0.698747
#
# Missing Values for CBL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for CBL:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.222461 -0.225802 -0.227444 -0.230164
# open                  -0.222461  1.000000  0.997060  0.997647  0.995708
# high                  -0.225802  0.997060  1.000000  0.997153  0.998087
# low                   -0.227444  0.997647  0.997153  1.000000  0.997967
# close                 -0.230164  0.995708  0.998087  0.997967  1.000000
# per_change            -0.007489 -0.038590  0.011485 -0.003381  0.039296
# traded_quantity        0.379468  0.120560  0.135259  0.109472  0.124914
# traded_amount          0.345741  0.226310  0.240761  0.216128  0.230632
#
#                  per_change  traded_quantity  traded_amount
# published_date    -0.007489         0.379468       0.345741
# open              -0.038590         0.120560       0.226310
# high               0.011485         0.135259       0.240761
# low               -0.003381         0.109472       0.216128
# close              0.039296         0.124914       0.230632
# per_change         1.000000         0.215316       0.198680
# traded_quantity    0.215316         1.000000       0.975137
# traded_amount      0.198680         0.975137       1.000000
#
# EDA results and plots for CBL have been saved into 'eda_results_CBL.joblib'
# Dataset Overview for CCBL:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1890 non-null   datetime64[ns]
#  1   open             1890 non-null   float64
#  2   high             1890 non-null   float64
#  3   low              1890 non-null   float64
#  4   close            1890 non-null   float64
#  5   per_change       1889 non-null   float64
#  6   traded_quantity  1890 non-null   float64
#  7   traded_amount    1890 non-null   float64
#  8   status           1890 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 133.0 KB
# None
#
# Descriptive Statistics for CCBL:
#                       published_date         open         high          low  \
# count                           1890  1890.000000  1890.000000  1890.000000
# mean   2018-08-08 16:16:45.714285824   257.058307   261.422714   252.701693
# min              2014-06-18 00:00:00   146.000000   148.000000   136.000000
# 25%              2016-07-12 06:00:00   183.000000   186.000000   179.250000
# 50%              2018-07-30 12:00:00   234.000000   239.000000   230.000000
# 75%              2020-10-03 06:00:00   314.000000   318.750000   310.000000
# max              2023-01-09 00:00:00   601.000000   615.000000   600.000000
# std                              NaN    85.393550    87.468799    83.736262
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1890.000000  1889.000000     1.890000e+03   1.890000e+03  1890.000000
# mean    256.938730     0.012266     5.196612e+04   1.309271e+07    -0.055556
# min     145.000000   -21.450000     5.000000e+01   1.535000e+04    -1.000000
# 25%     182.250000    -1.060000     1.142350e+04   2.764272e+06    -1.000000
# 50%     235.000000     0.000000     2.101500e+04   5.169314e+06     0.000000
# 75%     314.000000     0.880000     4.780875e+04   1.152310e+07     0.000000
# max     601.000000    10.000000     1.293222e+06   3.783755e+08     1.000000
# std      85.687033     2.204000     9.766329e+04   2.618245e+07     0.689929
#
# Missing Values for CCBL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for CCBL:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.580148 -0.579040 -0.582471 -0.583416
# open                  -0.580148  1.000000  0.998043  0.998478  0.997293
# high                  -0.579040  0.998043  1.000000  0.998081  0.998797
# low                   -0.582471  0.998478  0.998081  1.000000  0.998605
# close                 -0.583416  0.997293  0.998797  0.998605  1.000000
# per_change             0.007661 -0.021582  0.016350  0.007390  0.038048
# traded_quantity        0.386039 -0.033195 -0.020242 -0.038832 -0.028639
# traded_amount          0.315941  0.074828  0.088848  0.070120  0.080519
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.007661         0.386039       0.315941
# open              -0.021582        -0.033195       0.074828
# high               0.016350        -0.020242       0.088848
# low                0.007390        -0.038832       0.070120
# close              0.038048        -0.028639       0.080519
# per_change         1.000000         0.188700       0.191733
# traded_quantity    0.188700         1.000000       0.982692
# traded_amount      0.191733         0.982692       1.000000
#
# EDA results and plots for CCBL have been saved into 'eda_results_CCBL.joblib'
# Dataset Overview for CFCL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2434 entries, 0 to 2433
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   2434 non-null   datetime64[ns]
#  1   open             2434 non-null   float64
#  2   high             2434 non-null   float64
#  3   low              2434 non-null   float64
#  4   close            2434 non-null   float64
#  5   per_change       2433 non-null   float64
#  6   traded_quantity  2434 non-null   float64
#  7   traded_amount    2434 non-null   float64
#  8   status           2434 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 190.2 KB
# None
#
# Descriptive Statistics for CFCL:
#                       published_date         open         high          low  \
# count                           2434  2434.000000  2434.000000  2434.000000
# mean   2017-05-30 18:36:23.073130496   272.091532   276.788989   266.808418
# min              2003-06-06 00:00:00   105.000000   105.000000   104.000000
# 25%              2014-12-30 12:00:00   139.000000   141.000000   138.000000
# 50%              2019-03-17 12:00:00   210.000000   214.000000   206.000000
# 75%              2022-01-15 06:00:00   342.000000   348.800000   335.000000
# max              2024-08-15 00:00:00   960.000000   977.000000   928.000000
# std                              NaN   173.674812   176.839477   169.243628
#
#              close   per_change  traded_quantity  traded_amount       status
# count  2434.000000  2433.000000      2434.000000   2.434000e+03  2434.000000
# mean    271.584758     0.154603     16611.025472   7.179249e+06    -0.047658
# min     105.000000   -36.940000         1.000000   0.000000e+00    -1.000000
# 25%     140.000000    -1.690000       420.500000   1.751450e+04    -1.000000
# 50%     210.000000     0.000000      2765.500000   4.159035e+05     0.000000
# 75%     341.425000     1.640000     13690.250000   3.803783e+06     1.000000
# max     960.000000    58.580000    472295.000000   3.615137e+08     1.000000
# std     173.180713     3.958483     39064.977747   2.282714e+07     0.740045
#
# Missing Values for CFCL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for CFCL:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.044559  0.057725  0.031848  0.041533
# open                   0.044559  1.000000  0.997050  0.997369  0.996245
# high                   0.057725  0.997050  1.000000  0.998295  0.999147
# low                    0.031848  0.997369  0.998295  1.000000  0.998852
# close                  0.041533  0.996245  0.999147  0.998852  1.000000
# per_change            -0.002264 -0.016403  0.040408  0.032722  0.056019
# traded_quantity        0.337147  0.392934  0.414076  0.381649  0.399847
# traded_amount          0.267429  0.414167  0.433473  0.404325  0.420024
#
#                  per_change  traded_quantity  traded_amount
# published_date    -0.002264         0.337147       0.267429
# open              -0.016403         0.392934       0.414167
# high               0.040408         0.414076       0.433473
# low                0.032722         0.381649       0.404325
# close              0.056019         0.399847       0.420024
# per_change         1.000000         0.141213       0.108696
# traded_quantity    0.141213         1.000000       0.954436
# traded_amount      0.108696         0.954436       1.000000
#
# EDA results and plots for CFCL have been saved into 'eda_results_CFCL.joblib'
# Dataset Overview for CHCL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3987 entries, 0 to 3986
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   3987 non-null   datetime64[ns]
#  1   open             3987 non-null   float64
#  2   high             3987 non-null   float64
#  3   low              3987 non-null   float64
#  4   close            3987 non-null   float64
#  5   per_change       3986 non-null   float64
#  6   traded_quantity  3987 non-null   float64
#  7   traded_amount    3987 non-null   float64
#  8   status           3987 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 311.5 KB
# None
#
# Descriptive Statistics for CHCL:
#                       published_date         open         high          low  \
# count                           3987  3987.000000  3987.000000  3987.000000
# mean   2015-11-02 01:07:10.699774464   918.226436   928.716278   906.881139
# min              2006-06-13 00:00:00   281.000000   281.000000   276.000000
# 25%              2011-08-03 12:00:00   525.500000   533.000000   517.000000
# 50%              2015-12-31 00:00:00   829.000000   840.000000   820.000000
# 75%              2020-03-10 12:00:00  1180.000000  1200.000000  1170.000000
# max              2024-08-15 00:00:00  2742.000000  2794.000000  2720.000000
# std                              NaN   445.405005   450.440874   439.582238
#
#              close   per_change  traded_quantity  traded_amount       status
# count  3987.000000  3986.000000      3987.000000   3.987000e+03  3987.000000
# mean    918.151543     0.144099     17618.177075   1.246243e+07    -0.039378
# min     281.000000   -76.340000         5.000000   0.000000e+00    -1.000000
# 25%     523.500000    -1.020000      2450.000000   5.626000e+05     0.000000
# 50%     830.000000     0.000000      6536.000000   5.018396e+06     0.000000
# 75%    1180.000000     0.890000     15980.500000   1.249547e+07     0.000000
# max    2742.000000   330.480000    556516.000000   3.703120e+08     1.000000
# std     446.049229     6.198208     40308.335409   2.693089e+07     0.596616
#
# Missing Values for CHCL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for CHCL:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.479844 -0.475687 -0.483978 -0.480577
# open                  -0.479844  1.000000  0.995693  0.995963  0.995373
# high                  -0.475687  0.995693  1.000000  0.999037  0.999527
# low                   -0.483978  0.995963  0.999037  1.000000  0.999369
# close                 -0.480577  0.995373  0.999527  0.999369  1.000000
# per_change            -0.030648 -0.039568  0.032126  0.029367  0.036825
# traded_quantity        0.377634 -0.174819 -0.169548 -0.180776 -0.174122
# traded_amount          0.324045  0.034899  0.043029  0.029756  0.037792
#
#                  per_change  traded_quantity  traded_amount
# published_date    -0.030648         0.377634       0.324045
# open              -0.039568        -0.174819       0.034899
# high               0.032126        -0.169548       0.043029
# low                0.029367        -0.180776       0.029756
# close              0.036825        -0.174122       0.037792
# per_change         1.000000         0.047616       0.038717
# traded_quantity    0.047616         1.000000       0.946417
# traded_amount      0.038717         0.946417       1.000000
#
# EDA results and plots for CHCL have been saved into 'eda_results_CHCL.joblib'
# Dataset Overview for CHL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1537 entries, 0 to 1536
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1537 non-null   datetime64[ns]
#  1   open             1537 non-null   float64
#  2   high             1537 non-null   float64
#  3   low              1537 non-null   float64
#  4   close            1537 non-null   float64
#  5   per_change       1536 non-null   float64
#  6   traded_quantity  1537 non-null   float64
#  7   traded_amount    1537 non-null   float64
#  8   status           1537 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 120.1 KB
# None
#
# Descriptive Statistics for CHL:
#                       published_date         open         high          low  \
# count                           1537  1537.000000  1537.000000  1537.000000
# mean   2021-04-02 17:36:48.718282240   235.802147   241.731360   229.986077
# min              2017-09-17 00:00:00    74.000000    75.000000    74.000000
# 25%              2019-06-12 00:00:00   120.000000   122.000000   119.000000
# 50%              2021-05-19 00:00:00   207.000000   211.000000   202.900000
# 75%              2022-12-22 00:00:00   308.500000   318.000000   302.100000
# max              2024-08-15 00:00:00   685.000000   715.000000   655.000000
# std                              NaN   133.058801   137.792211   127.779752
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1537.000000  1536.000000      1537.000000   1.537000e+03  1537.000000
# mean    235.679115     0.127806     15322.255042   5.669616e+06    -0.064411
# min      75.000000    -9.880000        10.000000   7.800000e+02    -1.000000
# 25%     120.000000    -1.750000       208.000000   2.614800e+04    -1.000000
# 50%     206.700000     0.000000      5587.000000   1.247210e+06     0.000000
# 75%     310.000000     1.552500     19771.000000   5.709319e+06     1.000000
# max     679.000000    10.000000    221847.000000   1.156902e+08     1.000000
# ...
# traded_amount          0.239022  0.615642  0.630056  0.615477  0.626878
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.043634         0.339579       0.239022
# open              -0.013026         0.551023       0.615642
# high               0.018981         0.566244       0.630056
# low                0.011089         0.549669       0.615477
# close              0.046759         0.563343       0.626878
# per_change         1.000000         0.225586       0.178179
# traded_quantity    0.225586         1.000000       0.921271
# traded_amount      0.178179         0.921271       1.000000
#
# EDA results and plots for SPDL have been saved into 'eda_results_SPDL.joblib'
# Dataset Overview for SRBL:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2783 entries, 0 to 2782
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   2783 non-null   datetime64[ns]
#  1   open             2783 non-null   float64
#  2   high             2783 non-null   float64
#  3   low              2783 non-null   float64
#  4   close            2783 non-null   float64
#  5   per_change       2782 non-null   float64
#  6   traded_quantity  2783 non-null   float64
#  7   traded_amount    2783 non-null   float64
#  8   status           2783 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 195.8 KB
# None
#
# Descriptive Statistics for SRBL:
#                       published_date         open         high          low  \
# count                           2783  2783.000000  2783.000000  2783.000000
# mean   2017-06-26 09:53:29.342436096   303.066691   307.857600   298.012037
# min              2011-05-23 00:00:00   115.000000   115.000000   112.000000
# 25%              2014-06-13 12:00:00   212.000000   214.000000   209.000000
# 50%              2017-06-27 00:00:00   252.000000   255.000000   249.000000
# 75%              2020-08-19 12:00:00   390.000000   395.000000   385.000000
# max              2023-07-13 00:00:00   988.000000  1024.000000   960.000000
# std                              NaN   142.736933   145.504129   140.216862
#
#              close   per_change  traded_quantity  traded_amount       status
# count  2783.000000  2782.000000      2783.000000   2.783000e+03  2783.000000
# mean    303.132124     0.044601     25567.954725   8.579663e+06    -0.039166
# min     115.000000   -27.370000        20.000000   2.900000e+03    -1.000000
# 25%     212.000000    -1.170000      3469.500000   9.488490e+05     0.000000
# 50%     252.000000     0.000000      9065.000000   2.635792e+06     0.000000
# 75%     390.000000     1.037500     25374.500000   7.521510e+06     0.000000
# max     988.000000    19.690000    786500.000000   3.066348e+08     1.000000
# std     143.083467     2.460898     51414.993601   1.894673e+07     0.631298
#
# Missing Values for SRBL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for SRBL:
#                  published_date      open      high       low     close  \
# published_date         1.000000 -0.057044 -0.059105 -0.055679 -0.060192
# open                  -0.057044  1.000000  0.998970  0.999217  0.998484
# high                  -0.059105  0.998970  1.000000  0.999015  0.999358
# low                   -0.055679  0.999217  0.999015  1.000000  0.999224
# close                 -0.060192  0.998484  0.999358  0.999224  1.000000
# per_change            -0.033557 -0.017667  0.010379  0.002985  0.026053
# traded_quantity        0.384780  0.114245  0.120539  0.110058  0.115108
# traded_amount          0.288569  0.293033  0.300238  0.289403  0.294620
#
#                  per_change  traded_quantity  traded_amount
# published_date    -0.033557         0.384780       0.288569
# open              -0.017667         0.114245       0.293033
# high               0.010379         0.120539       0.300238
# low                0.002985         0.110058       0.289403
# close              0.026053         0.115108       0.294620
# per_change         1.000000         0.097308       0.093969
# traded_quantity    0.097308         1.000000       0.952339
# traded_amount      0.093969         0.952339       1.000000
#
# EDA results and plots for SRBL have been saved into 'eda_results_SRBL.joblib'
# Dataset Overview for UMHL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1637 entries, 0 to 1636
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1637 non-null   datetime64[ns]
#  1   open             1637 non-null   float64
#  2   high             1637 non-null   float64
#  3   low              1637 non-null   float64
#  4   close            1637 non-null   float64
#  5   per_change       1636 non-null   float64
#  6   traded_quantity  1637 non-null   float64
#  7   traded_amount    1637 non-null   float64
#  8   status           1637 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 127.9 KB
# None
#
# Descriptive Statistics for UMHL:
#                       published_date         open         high          low  \
# count                           1637  1637.000000  1637.000000  1637.000000
# mean   2021-01-25 12:04:50.287110656   226.112156   231.433232   220.467135
# min              2017-06-13 00:00:00    97.000000    98.000000    96.000000
# 25%              2019-03-14 00:00:00   154.000000   158.000000   150.000000
# 50%              2021-03-03 00:00:00   218.000000   223.000000   213.000000
# 75%              2022-11-14 00:00:00   270.500000   276.000000   263.100000
# max              2024-08-15 00:00:00   632.000000   646.600000   620.000000
# std                              NaN   104.302223   107.747746   100.138625
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1637.000000  1636.000000     1.637000e+03   1.637000e+03  1637.000000
# mean    225.593647     0.049933     6.340940e+04   2.211554e+07    -0.112401
# min      98.000000    -9.290000     1.000000e+01   1.220000e+03    -1.000000
# 25%     155.000000    -1.820000     1.237000e+03   1.800040e+05    -1.000000
# 50%     217.000000    -0.135000     1.615300e+04   3.399092e+06     0.000000
# 75%     270.000000     1.500000     6.304400e+04   1.539716e+07     1.000000
# max     630.000000    10.000000     1.160147e+06   6.192917e+08     1.000000
# std     103.320585     3.088313     1.259387e+05   5.549796e+07     0.898694
#
# Missing Values for UMHL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for UMHL:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.295997  0.300970  0.294719  0.295733
# open                   0.295997  1.000000  0.998347  0.998573  0.996449
# high                   0.300970  0.998347  1.000000  0.998374  0.998663
# low                    0.294719  0.998573  0.998374  1.000000  0.998314
# close                  0.295733  0.996449  0.998663  0.998314  1.000000
# per_change             0.048443 -0.027237  0.010145 -0.001427  0.042007
# traded_quantity        0.255471  0.586730  0.605608  0.581753  0.600228
# traded_amount          0.189557  0.646913  0.663981  0.643613  0.659487
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.048443         0.255471       0.189557
# open              -0.027237         0.586730       0.646913
# high               0.010145         0.605608       0.663981
# low               -0.001427         0.581753       0.643613
# close              0.042007         0.600228       0.659487
# per_change         1.000000         0.206554       0.157715
# traded_quantity    0.206554         1.000000       0.949445
# traded_amount      0.157715         0.949445       1.000000
#
# EDA results and plots for UMHL have been saved into 'eda_results_UMHL.joblib'
# Dataset Overview for UNHPL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1137 entries, 0 to 1136
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1137 non-null   datetime64[ns]
#  1   open             1137 non-null   float64
#  2   high             1137 non-null   float64
#  3   low              1137 non-null   float64
#  4   close            1137 non-null   float64
#  5   per_change       1137 non-null   float64
#  6   traded_quantity  1137 non-null   float64
#  7   traded_amount    1137 non-null   float64
#  8   status           1137 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 88.8 KB
# None
#
# Descriptive Statistics for UNHPL:
#                       published_date         open         high          low  \
# count                           1137  1137.000000  1137.000000  1137.000000
# mean   2022-03-08 21:53:21.055408896   205.951055   211.562841   199.952410
# min              2019-07-24 00:00:00    48.020000    49.000000    48.020000
# 25%              2021-01-11 00:00:00   121.000000   123.000000   117.000000
# 50%              2022-03-23 00:00:00   210.000000   215.200000   204.100000
# 75%              2023-05-31 00:00:00   251.500000   259.500000   245.000000
# max              2024-08-15 00:00:00   571.000000   612.000000   558.000000
# std                              NaN   108.280483   111.984096   104.054828
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1137.000000  1137.000000      1137.000000   1.137000e+03  1137.000000
# mean    205.262313     0.176007     36151.273527   9.524129e+06    -0.104661
# min      49.000000   -10.000000        25.000000   1.450000e+03    -1.000000
# 25%     120.000000    -2.020000      7880.000000   1.460810e+06    -1.000000
# 50%     209.000000     0.000000     20105.000000   3.988501e+06    -1.000000
# 75%     251.000000     1.900000     42723.000000   1.061538e+07     1.000000
# max     560.000000    10.000000    408828.000000   1.594823e+08     1.000000
# std     107.468989     3.701667     47057.524882   1.479078e+07     0.950605
#
# Missing Values for UNHPL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         0
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for UNHPL:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.435677  0.428950  0.446871  0.438117
# open                   0.435677  1.000000  0.998529  0.998514  0.996541
# high                   0.428950  0.998529  1.000000  0.998305  0.998547
# low                    0.446871  0.998514  0.998305  1.000000  0.998194
# close                  0.438117  0.996541  0.998547  0.998194  1.000000
# per_change             0.003480 -0.029211  0.004400 -0.002035  0.038823
# traded_quantity        0.293395  0.404371  0.420980  0.400069  0.419431
# traded_amount          0.235313  0.553804  0.570190  0.548945  0.567511
#
#                  per_change  traded_quantity  traded_amount
# published_date     0.003480         0.293395       0.235313
# open              -0.029211         0.404371       0.553804
# high               0.004400         0.420980       0.570190
# low               -0.002035         0.400069       0.548945
# close              0.038823         0.419431       0.567511
# per_change         1.000000         0.238937       0.191818
# traded_quantity    0.238937         1.000000       0.933617
# traded_amount      0.191818         0.933617       1.000000
#
# EDA results and plots for UNHPL have been saved into 'eda_results_UNHPL.joblib'
# Dataset Overview for UPCL:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1187 entries, 0 to 1186
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   1187 non-null   datetime64[ns]
#  1   open             1187 non-null   float64
#  2   high             1187 non-null   float64
#  3   low              1187 non-null   float64
#  4   close            1187 non-null   float64
#  5   per_change       1187 non-null   float64
#  6   traded_quantity  1187 non-null   float64
#  7   traded_amount    1187 non-null   float64
#  8   status           1187 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 92.7 KB
# None
#
# Descriptive Statistics for UPCL:
#                       published_date         open         high          low  \
# count                           1187  1187.000000  1187.000000  1187.000000
# mean   2022-01-27 02:29:12.990733056   210.490396   215.953412   204.502864
# min              2019-05-21 00:00:00    66.000000    67.000000    66.000000
# 25%              2020-11-18 12:00:00   133.000000   136.500000   130.000000
# 50%              2022-02-10 00:00:00   209.900000   214.200000   205.100000
# 75%              2023-05-10 12:00:00   254.500000   260.000000   248.050000
# max              2024-08-15 00:00:00   605.000000   635.000000   590.000000
# std                              NaN   105.986226   109.658430   101.507598
#
#              close   per_change  traded_quantity  traded_amount       status
# count  1187.000000  1187.000000     1.187000e+03   1.187000e+03  1187.000000
# mean    209.583993     0.171955     9.504446e+04   2.674430e+07    -0.135636
# min      67.000000   -10.000000     1.000000e+01   7.300000e+02    -1.000000
# 25%     133.000000    -1.595000     2.168750e+04   3.869443e+06    -1.000000
# 50%     209.000000    -0.240000     5.464100e+04   1.123834e+07    -1.000000
# 75%     254.000000     1.530000     1.104215e+05   2.770813e+07     1.000000
# max     610.000000    10.000000     1.035032e+06   5.481026e+08     1.000000
# std     105.055551     3.326588     1.244046e+05   4.702833e+07     0.945907
#
# Missing Values for UPCL:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         0
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64
#
# Correlation Matrix for UPCL:
#                  published_date      open      high       low     close  \
# published_date         1.000000  0.413276  0.403851  0.425210  0.414230
# open                   0.413276  1.000000  0.998413  0.998626  0.996286
# high                   0.403851  0.998413  1.000000  0.998287  0.998574
# low                    0.425210  0.998626  0.998287  1.000000  0.998078
# close                  0.414230  0.996286  0.998574  0.998078  1.000000
# per_change            -0.000943 -0.033166  0.003323 -0.006751  0.038607
# traded_quantity        0.188957  0.503417  0.523995  0.499193  0.522947
# traded_amount          0.120901  0.621825  0.642113  0.619083  0.640748
#
#                  per_change  traded_quantity  traded_amount
# published_date    -0.000943         0.188957       0.120901
# open              -0.033166         0.503417       0.621825
# high               0.003323         0.523995       0.642113
# low               -0.006751         0.499193       0.619083
# close              0.038607         0.522947       0.640748
# per_change         1.000000         0.282047       0.213449
# traded_quantity    0.282047         1.000000       0.918993
# traded_amount      0.213449         0.918993       1.000000
#
# EDA results and plots for UPCL have been saved into 'eda_results_UPCL.joblib'
